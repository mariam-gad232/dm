# %%
import pandas as pd
Data=pd.read_csv("E-commerce Website Logs.csv")
Data
# Out:
# C:\Users\Compu City\AppData\Local\Temp\ipykernel_276\3476879458.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   Data=pd.read_csv("E-commerce Website Logs.csv")
#        accessed_date  duration_(secs) network_protocol               ip  \
# 0            43:57.2             2533            TCP       1.10.195.126
# 1            43:57.2             4034            TCP        1.1.217.211
# 2            43:26.1             1525            TCP      1.115.198.107
# 3            43:26.1             4572            TCP      1.121.152.143
# 4            17:09.0             3652            TCP      1.123.135.213
# ...              ...              ...              ...              ...
# 172833       42:01.3             4372            TCP     94.197.121.229
# 172834       10:17.3             2167            TCP     129.110.241.72
# 172835       10:17.3             2725            TCP    185.119.252.121
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172838 entries, 0 to 172837
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   accessed_date     172838 non-null  object
#  1   duration_(secs)   172838 non-null  int64
#  2   network_protocol  172838 non-null  object
#  3   ip                172838 non-null  object
#  4   bytes             172838 non-null  int64
#  5   accessed_Ffom     172838 non-null  object
#  6   age               99457 non-null   object
#  7   gender            172838 non-null  object
#  8   country           172838 non-null  object
#  9   membership        172835 non-null  object
#  10  language          172835 non-null  object
#  11  sales             172838 non-null  float64
#  12  returned          172831 non-null  object
#  13  returned_amount   172838 non-null  float64
#  14  pay_method        172838 non-null  object
# dtypes: float64(2), int64(2), object(11)
# ...

# %%
Data.describe()
# Out:
#        duration_(secs)          bytes          sales  returned_amount
# count    172838.000000  172838.000000  172838.000000    172838.000000
# mean       3248.031827    1535.206858     411.346449        74.012092
# std        1010.872270    6349.555845     785.537868       364.446435
# min        1500.000000      28.000000       0.000000         0.000000
# 25%        2371.000000     264.000000       5.230000         0.000000
# 50%        3246.000000     589.000000      46.920000         0.000000
# 75%        4124.000000    2430.000000     600.160000         0.000000
# max        5000.000000  932858.000000   11199.968000     22638.480000

# %%
Data.shape
# Out:
# (172838, 15)

# %%
Data.index
# Out:
# RangeIndex(start=0, stop=172838, step=1)

# %%
Data.sample(frac=0.2)
# Out:
#        accessed_date  duration_(secs) network_protocol               ip  \
# 99920        31:42.4             1577            TCP       2.219.40.242
# 117701       17:40.1             2180            TCP    197.228.147.141
# 27769        18:00.3             4327            TCP      87.76.241.142
# 12051        36:54.9             2034             HTTP     113.185.41.4
# 62231        18:14.8             4566            TCP     42.112.179.202
# ...              ...              ...              ...              ...
# 72394        02:09.4             4542            TCP       118.50.41.13
# 124253       14:25.4             3210            TCP      68.231.66.209
# 56623        41:40.1             2834            TCP       185.3.134.61
# 147          03:24.8             1775            TCP        1.39.63.230
# 121814       19:46.0             4385            TCP       41.190.29.75
#
#         bytes    accessed_Ffom  age   gender country     membership language  \
# ...

# %%
Data.isnull().sum()
# Out:
# accessed_date           0
# duration_(secs)         0
# network_protocol        0
# ip                      0
# bytes                   0
# accessed_Ffom           0
# age                 73381
# gender                  0
# country                 0
# membership              3
# language                3
# sales                   0
# returned                7
# returned_amount         0
# pay_method              0
# dtype: int64

# %%
Data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 172833    False
# 172834    False
# 172835    False
# 172836    False
# 172837    False
# Length: 172838, dtype: bool

# %%
Data.isnull()
# Out:
#         accessed_date  duration_(secs)  network_protocol     ip  bytes  \
# 0               False            False             False  False  False
# 1               False            False             False  False  False
# 2               False            False             False  False  False
# 3               False            False             False  False  False
# 4               False            False             False  False  False
# ...               ...              ...               ...    ...    ...
# 172833          False            False             False  False  False
# 172834          False            False             False  False  False
# 172835          False            False             False  False  False
# 172836          False            False             False  False  False
# 172837          False            False             False  False  False
#
#         accessed_Ffom    age  gender  country  membership  language  sales  \
# ...

# %%
Data['age'] = pd.to_numeric(Data['age'], errors='coerce',downcast='integer')

# %%
Data['age']=Data['age'].fillna(Data['age'].mode()[0])
Data
# Out:
#        accessed_date  duration_(secs) network_protocol               ip  \
# 0            43:57.2             2533            TCP       1.10.195.126
# 1            43:57.2             4034            TCP        1.1.217.211
# 2            43:26.1             1525            TCP      1.115.198.107
# 3            43:26.1             4572            TCP      1.121.152.143
# 4            17:09.0             3652            TCP      1.123.135.213
# ...              ...              ...              ...              ...
# 172833       42:01.3             4372            TCP     94.197.121.229
# 172834       10:17.3             2167            TCP     129.110.241.72
# 172835       10:17.3             2725            TCP    185.119.252.121
# 172836       52:58.3             3728            TCP     185.145.107.23
# 172837       52:58.3             3420            TCP      202.69.12.251
#
#          bytes    accessed_Ffom  age  gender country membership language  \
# ...

# %%
Data['language']=Data['language'].fillna(Data['language'].mode()[0])
Data
# Out:
#        accessed_date  duration_(secs) network_protocol               ip  \
# 0            43:57.2             2533            TCP       1.10.195.126
# 1            43:57.2             4034            TCP        1.1.217.211
# 2            43:26.1             1525            TCP      1.115.198.107
# 3            43:26.1             4572            TCP      1.121.152.143
# 4            17:09.0             3652            TCP      1.123.135.213
# ...              ...              ...              ...              ...
# 172833       42:01.3             4372            TCP     94.197.121.229
# 172834       10:17.3             2167            TCP     129.110.241.72
# 172835       10:17.3             2725            TCP    185.119.252.121
# 172836       52:58.3             3728            TCP     185.145.107.23
# 172837       52:58.3             3420            TCP      202.69.12.251
#
#          bytes    accessed_Ffom  age  gender country membership language  \
# ...

# %%
Data['membership'].fillna('Normal', inplace=True)
Data
# Out:
#        accessed_date  duration_(secs) network_protocol               ip  \
# 0            43:57.2             2533            TCP       1.10.195.126
# 1            43:57.2             4034            TCP        1.1.217.211
# 2            43:26.1             1525            TCP      1.115.198.107
# 3            43:26.1             4572            TCP      1.121.152.143
# 4            17:09.0             3652            TCP      1.123.135.213
# ...              ...              ...              ...              ...
# 172833       42:01.3             4372            TCP     94.197.121.229
# 172834       10:17.3             2167            TCP     129.110.241.72
# 172835       10:17.3             2725            TCP    185.119.252.121
# 172836       52:58.3             3728            TCP     185.145.107.23
# 172837       52:58.3             3420            TCP      202.69.12.251
#
#          bytes    accessed_Ffom  age  gender country membership language  \
# ...

# %%
Data['returned']=Data['returned'].fillna(Data['returned'].mode()[0])
Data
# Out:
#        accessed_date  duration_(secs) network_protocol               ip  \
# 0            43:57.2             2533            TCP       1.10.195.126
# 1            43:57.2             4034            TCP        1.1.217.211
# 2            43:26.1             1525            TCP      1.115.198.107
# 3            43:26.1             4572            TCP      1.121.152.143
# 4            17:09.0             3652            TCP      1.123.135.213
# ...              ...              ...              ...              ...
# 172833       42:01.3             4372            TCP     94.197.121.229
# 172834       10:17.3             2167            TCP     129.110.241.72
# 172835       10:17.3             2725            TCP    185.119.252.121
# 172836       52:58.3             3728            TCP     185.145.107.23
# 172837       52:58.3             3420            TCP      202.69.12.251
#
#          bytes    accessed_Ffom  age  gender country membership language  \
# ...

# %%
Data.isnull().sum()
# Out:
# accessed_date       0
# duration_(secs)     0
# network_protocol    0
# ip                  0
# bytes               0
# accessed_Ffom       0
# age                 0
# gender              0
# country             0
# membership          0
# language            0
# sales               0
# returned            0
# returned_amount     0
# pay_method          0
# dtype: int64

# %%
Data.duplicated().sum()
# Out:
# 0
